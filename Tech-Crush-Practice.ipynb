# %%
# !pip install pandas

# %%
# !pip install seaborn

# %%
# !pip install matplotlib

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import pandas as pd   # This imports the pandas library and gives it the alias 'pd' for easier use
import seaborn as sns # This imports the seaborn library and gives it the alias 'sns' for easier use
import matplotlib.pyplot as plt   # This imports the pyplot module from the matplotlib library and gives it the alias 'plt' for easier use
import numpy as np   # This imports the numpy library and gives it the alias 'np' for easier use

# %%
path = "C:\\Users\\NI\\Documents\\GITHUB\\TechCrush\\insurance_claims.csv"   # This is the path to the CSV file you want to load
df = pd.read_csv(path)   # This loads the file into a DataFrame called df

# %%
df.info()   # This displays a summary of the DataFrame, including the number of non-null entries and the data types of each column

# %%
df.head(5)   # This displays the first 5 rows of the DataFrame, allowing you to see the structure and contents of the data

# %%
df.describe()   # This generates descriptive statistics of the DataFrame, such as mean, standard deviation, minimum, and maximum values for each numeric column

# %%
missing_values = df.isnull().sum()   # This calculates the number of missing values in each column of the DataFrame by checking for null values and summing them up
print (missing_values)  # This prints the number of missing values for each column to the console, allowing you to see which columns have missing data and how many missing values they contain

# %%
if "_c39" in df.columns:   # This checks if the column named "_c39" exists in the DataFrame's columns. If it does, the code inside the if block will be executed.
  df = df.drop("_c39", axis=1)   # This drops the column named "_c39" from the DataFrame. The axis=1 parameter specifies that we want to drop a column (as opposed to a row, which would be axis=0). After this operation, the DataFrame will no longer contain the "_c39" column.
