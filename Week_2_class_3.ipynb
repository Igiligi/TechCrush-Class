# %% [markdown]
# <a href="https://colab.research.google.com/github/Igiligi/TechCrush-Class/blob/main/Week_2_class_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(3):
  print("Hello AI Scholars")
# Out:
# Hello AI Scholars
# Hello AI Scholars
# Hello AI Scholars

# %%
water_temp_celsius = 32.5
dissolved_oxygen_mg_l = 4.2

print("--- Bodunde Aquaculture Sensor Check ---")

if dissolved_oxygen_mg_l < 5.0:
    print("ALERT: Oxygen levels critical! Activating aeration pump.")
elif water_temp_celsius > 30.0:
    print("WARNING: Temperature high. Activating cooling system.")
else:
    print("STATUS: Pond environment is optimal.")
# Out:
# --- Bodunde Aquaculture Sensor Check ---
# ALERT: Oxygen levels critical! Activating aeration pump.
